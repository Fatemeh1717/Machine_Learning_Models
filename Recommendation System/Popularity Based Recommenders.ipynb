# %% [markdown]
# # Recommender System
# ## Popularity Based Recommenders

# %%
import pandas as pd
import numpy as np

# %%
frame= pd.read_csv('C:/Users/HP/Desktop/Ex_Files_Intro_Python_Rec_Systems/Ex_Files_Intro_Python_Rec_Systems/Exercise Files/01_02/rating_final.csv')
frame.head()
# Out:
#   userID  placeID  rating  food_rating  service_rating
# 0  U1077   135085       2            2               2
# 1  U1077   135038       2            2               1
# 2  U1077   132825       2            2               2
# 3  U1077   135060       1            2               2
# 4  U1068   135104       1            1               2

# %%
cuisine= pd.read_csv('C:/Users/HP/Desktop/Ex_Files_Intro_Python_Rec_Systems/Ex_Files_Intro_Python_Rec_Systems/Exercise Files/01_02/chefmozcuisine.csv')
cuisine.head()
# Out:
#    placeID        Rcuisine
# 0   135110         Spanish
# 1   135109         Italian
# 2   135107  Latin_American
# 3   135106         Mexican
# 4   135105       Fast_Food

# %% [markdown]
# ### Recommending Base on Count

# %%
rating_count = pd .DataFrame(frame.groupby('placeID')['rating'].count())
rating_count.sort_values('rating', ascending = False).head()
# Out:
#          rating
# placeID
# 135085       36
# 132825       32
# 135032       28
# 135052       25
# 132834       25

# %%
most_rated_places = pd. DataFrame([135085,132825,135032,135052,132834], index = np.arange(5), columns=['placeID'])
summary = pd.merge(most_rated_places, cuisine, on='placeID')
summary
# Out:
#    placeID         Rcuisine
# 0   135085        Fast_Food
# 1   132825          Mexican
# 2   135032        Cafeteria
# 3   135032     Contemporary
# 4   135052              Bar
# 5   135052  Bar_Pub_Brewery
# 6   132834          Mexican

# %%
cuisine['Rcuisine'].describe()
# Out:
# count         916
# unique         59
# top       Mexican
# freq          239
# Name: Rcuisine, dtype: object
